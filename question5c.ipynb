# %%
import pandas as pd
import sqlite3

# %%
wiki=pd.read_excel(r'E:\programming\Data Science Course\Group project files\flatten_data_table-main\wikipedia_dataset_flat.xlsx',sheet_name='Sheet2')
wiki
# Out:
#    Month        Mon       Tues       Wed        Thur        Fri        Sat  \
# 0    Jan  333576430  321629527  320914771  314746359  373792534  378954342
# 1    Feb  429846934  334013411  330781780  316432168  303439770  299503952
# 2    Mar  313809656  383190121  383726792  373534683  291068892  288572762
# 3    Apr  327832800  315872479  310412951  304346236  355043756  353225115
# 4    May  401272065  388812287  307462545  299757883  284774567  283596174
# 5    Jun  336298797  315955227  389514527  384069310  289362499  291407445
# 6    Jul  455569869  448201569  482091753  495024150  571550505  571536391
# 7    Aug  760425662  747898125  639745293  495769601  484679237  496231009
# 8    Sep  365152498  354796016  353106053  461208255  430247000  360540476
# 9    Oct  458590813  351633573  356609928  362253912  313625234  410250941
# 10   Nov  360380276  442020689  455665459  349872423  321591908  336003251
# ...

# %%
conn=sqlite3.connect('SumDayMonth.db')

# %%
c=conn.cursor()

# %%
create_columns="CREATE TABLE Daymonthvisits(Month TEXT,Mon INT,Tues INT,Wed INT,Thur INT,Fri INT,Sat INT,Sun INT)"

# %%
c.execute(create_columns)
conn.commit()

# %%
wiki.to_sql('Daymonthvisits',conn,if_exists='append',index=False)
# Out:
# F:\anaconda\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\BERYLC~1\AppData\Local\Temp/ipykernel_8264/730875315.py in <module>
# ----> 1 wiki.to_sql('Daymonthvisits',conn,if_exists='append',index=False)
#
# F:\anaconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# F:\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
# ...
